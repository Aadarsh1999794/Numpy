# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
img = np.array(plt.imread('hmm.jpg'))
plt.imshow(img)

# %%
print('dims',img.ndim)
print('shape',img.shape)
# Out:
# dims 3
# shape (252, 372, 4)

# %%
img = np.array(plt.imread('hmm.jpg'))

img_R, img_G, img_B = img.copy(), img.copy(), img.copy()

img_R[:, :, (1, 2)] = 0
img_G[:, :, (0, 2)] = 0
img_B[:, :, (0, 1)] = 0

# %%
plt.imshow(img_R)

# %%
plt.imshow(img_G)

# %%
plt.imshow(img_B)

# %%
img_R_grayscale = img[:,:,0] # 0 measne only red colour are visible

# %%
plt.imshow(img_R_grayscale)

# %%
plt.imshow(img_R_grayscale, cmap='gray')  #this is for blank and white

# %%
img = np.array(plt.imread('hmm.jpg'))
img_rotated = np.transpose(img, (1,0,2))
plt.imshow(img_rotated)
